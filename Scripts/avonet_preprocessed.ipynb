# %% [markdown]
# # Predicting diet proportions of all known extinct bird species using Random Forest
#
# ## PART 1. DATASET PRE-PROCESSING
#
# This script contains the code used to pre-process the datasets to train a RF model.
#
# ### Loading packages
#
# First, the necessary Python libraries are imported. These include pandas for data manipulation, scikit-learn for machine learning functionalities, matplotlib and seaborn for data visualization, and numpy for numerical operations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import numpy as np

# %% [markdown]
# # 1. Pre-processing of AVONET dataset
#
# ## 1.1 Load AVONET dataset
#
# We used a comprehensive dataset that combines information on the diets of extant bird species obtained from Tobias, J. et al., 2021.
# The code reads an excel file containing bird data using pd.read_xlsx() and stores it in a pandas DataFrame named data.

# %%
url = "https://github.com/martinezrubio/ECOTREX/raw/refs/heads/main/data/raw/AVONET_2022.xlsx"
data = pd.read_excel(url)
data.head()
# Out:
#                 Species3       Family3           Order3  Total.individuals  \
# 0  Accipiter albogularis  Accipitridae  Accipitriformes                  5
# 1       Accipiter badius  Accipitridae  Accipitriformes                 10
# 2      Accipiter bicolor  Accipitridae  Accipitriformes                  6
# 3   Accipiter brachyurus  Accipitridae  Accipitriformes                  4
# 4     Accipiter brevipes  Accipitridae  Accipitriformes                  8
#
#    Female  Male  Unknown  Complete.measures  Beak.Length_Culmen  \
# 0       2     0        3                  4                27.7
# 1       4     6        0                  8                20.6
# 2       2     2        2                  4                26.5
# 3       4     0        0                  3                22.5
# 4       4     4        0                  4                21.1
#
#    Beak.Length_Nares  ...  Migration  Trophic.Level  Trophic.Niche  \
# 0               17.8  ...        2.0      Carnivore      Vertivore
# 1               12.1  ...        3.0      Carnivore      Vertivore
# 2               14.8  ...        2.0      Carnivore      Vertivore
# 3               14.0  ...        2.0      Carnivore      Vertivore
# 4               12.1  ...        3.0      Carnivore      Vertivore
#
#    Primary.Lifestyle  Min.Latitude  Max.Latitude  Centroid.Latitude  \
# 0        Insessorial        -11.73         -4.02              -8.15
# 1        Insessorial        -29.47         46.39               8.23
# 2         Generalist           NaN           NaN                NaN
# 3        Insessorial         -6.31         -4.08              -5.45
# 4         Generalist         31.19         55.86              45.24
#
#    Centroid.Longitude   Range.Size Species.Status
# 0          158.493765     37461.21         Extant
# 1           44.982464  22374973.00         Extant
# 2                 NaN          NaN         Extant
# 3          150.681314     35580.71         Extant
# 4           45.327340   2936751.80         Extant
#
# [5 rows x 36 columns]

# %%
data.shape # Should be 9993 rows and 36 columns
# Out:
# (9993, 36)

# %%
data.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'Total.individuals', 'Female', 'Male',
#        'Unknown', 'Complete.measures', 'Beak.Length_Culmen',
#        'Beak.Length_Nares', 'Beak.Width', 'Beak.Depth', 'Tarsus.Length',
#        'Wing.Length', 'Kipps.Distance', 'Secondary1', 'Hand-Wing.Index',
#        'Tail.Length', 'Mass', 'Mass.Source', 'Mass.Refs.Other', 'Inference',
#        'Traits.inferred', 'Reference.species', 'Habitat', 'Habitat.Density',
#        'Migration', 'Trophic.Level', 'Trophic.Niche', 'Primary.Lifestyle',
#        'Min.Latitude', 'Max.Latitude', 'Centroid.Latitude',
#        'Centroid.Longitude', 'Range.Size', 'Species.Status'],
#       dtype='object')

# %% [markdown]
# ### 1.1.1 Exclusion of extinct species
#
# Species that are currently extinct or already represented in the AVOTREX dataset were excluded from the analysis to avoid duplication and ensure consistency between extant and extinct trait datasets.

# %%
species_to_remove = [
    "Acrocephalus luscinius",
    "Corvus hawaiiensis",
    "Cyanopsitta spixii",
    "Gallinula nesiotis",
    "Hemignathus lucidus",
    "Melamprosops phaeosoma",
    "Mitu mitu",
    "Philydor novaesi",
    "Prosobonia cancellata",
    "Todiramphus cinnamominus",
    "Zenaida graysoni",
    "Zosterops conspicillatus", 
    "Phyllastrephus leucolepis" # Removed as this species isn't considered a species anymore
]

# %%
data = data[~data["Species3"].isin(species_to_remove)]

# %%
data.shape # Should be 9980 rows and 36 columns
# Out:
# (9980, 36)

# %% [markdown]
# ### 1.1.2 Remove non-informative variables
#
# Non-informative metadata variables not used as predictors were removed to simplify the dataset prior to analysis.

# %%
cols_to_drop = [
    "Total.individuals",
    "Female",
    "Male",
    "Unknown",
    "Complete.measures",
    "Beak.Length_Nares",  # Removed as it was highly correlated with Beak.Length_Culmen
    "Secondary1",      # Removed as it was highly correlated with Kipps Distance
    "Hand-Wing.Index", # Removed as it was highly correlated with Kipps Distance
    "Mass.Source",
    "Mass.Refs.Other",
    "Inference",
    "Traits.inferred",
    "Reference.species",
    "Species.Status",
    "Habitat",         # Removed as we don't have enough information for extinct species to compare
    "Habitat.Density", # Removed as we don't have enough information for extinct species to compare
    "Migration",       # Removed as we don't have enough information for extinct species to compare
    "Trophic.Level",   # Removed as we don't have enough information for extinct species to compare
    "Trophic.Niche",   # Removed as we don't have enough information for extinct species to compare
    "Primary.Lifestyle", # Removed as we don't have enough information for extinct species to compare
    "Min.Latitude",    # Removed as we don't have enough information for extinct species to compare
    "Max.Latitude",    # Removed as we don't have enough information for extinct species to compare
    "Centroid.Latitude", # Removed as we don't have enough information for extinct species to compare
    "Centroid.Longitude", # Removed as we don't have enough information for extinct species to compare
    "Range.Size"       # Removed as we don't have enough information for extinct species to compare
]

# %%
data = data.drop(columns=cols_to_drop)

# %%
data.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'Beak.Length_Culmen', 'Beak.Width',
#        'Beak.Depth', 'Tarsus.Length', 'Wing.Length', 'Kipps.Distance',
#        'Tail.Length', 'Mass'],
#       dtype='object')

# %%
data.shape # Should be 9980 rows and 11 columns
# Out:
# (9980, 11)

# %% [markdown]
# ### 1.1.3 Log-transformation of morphological traits
#
# Morphological traits were log-transformed to account for allometric scaling and reduce skewness prior to analysis.

# %%
vars_to_log = [
    "Beak.Length_Culmen",
    "Beak.Width",
    "Beak.Depth",
    "Tarsus.Length",
    "Wing.Length",
    "Kipps.Distance",
    "Tail.Length",
    "Mass"
]

for var in vars_to_log:
    data[f"log_{var}"] = np.log(data[var])

# %%
data[[f"log_{v}" for v in vars_to_log]].describe()
# Out:
#        log_Beak.Length_Culmen  log_Beak.Width  log_Beak.Depth  \
# count             9980.000000     9980.000000     9980.000000
# mean                 3.076279        1.693549        1.831350
# std                  0.562332        0.578921        0.672284
# min                  1.504077       -0.356675        0.000000
# 25%                  2.681022        1.280934        1.335001
# 50%                  2.985682        1.609438        1.757858
# 75%                  3.349904        2.028148        2.240710
# max                  6.026349        4.487512        4.708629
#
#        log_Tarsus.Length  log_Wing.Length  log_Kipps.Distance  \
# count        9980.000000      9980.000000         9980.000000
# mean            3.172099         4.643163            3.121708
# std             0.590073         0.595676            0.984829
# min             0.916291        -2.302585           -2.302585
# 25%             2.862201         4.198705            2.388763
# 50%             3.091042         4.522875            2.983150
# 75%             3.456317         4.990433            3.793239
# max             6.163315         6.671906            6.037871
#
#        log_Tail.Length     log_Mass
# count      9980.000000  9980.000000
# mean          4.295238     3.904417
# std           0.569388     1.575007
# min          -2.302585     0.641854
# 25%           3.916015     2.705380
# 50%           4.225373     3.569533
# 75%           4.613138     4.820282
# max           6.700485    11.617285

# %%
cols_to_drop = [
    "Beak.Length_Culmen",
    "Beak.Width",
    "Beak.Depth",
    "Tarsus.Length",
    "Wing.Length",
    "Kipps.Distance",  
    "Tail.Length",      
    "Mass"    
]

# %%
data = data.drop(columns=cols_to_drop)

# %%
data.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'log_Beak.Length_Culmen',
#        'log_Beak.Width', 'log_Beak.Depth', 'log_Tarsus.Length',
#        'log_Wing.Length', 'log_Kipps.Distance', 'log_Tail.Length', 'log_Mass'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Incorporation of flight ability and island endemicity data
#
# Flight ability and island endemicity information were imported from an external AVONET-derived dataset and integrated with the main trait database for downstream analyses.

# %%
url = "https://raw.githubusercontent.com/martinezrubio/ECOTREX/main/data/raw/AVONET_flight_endemicity.csv"
endemicity = pd.read_csv(url)
endemicity.head()
# Out:
#                  species Island_Endemicity  Flight_Ability
# 0  Accipiter_albogularis               yes             1.0
# 1       Accipiter_badius                no             1.0
# 2      Accipiter_bicolor                no             1.0
# 3   Accipiter_brachyurus               yes             1.0
# 4     Accipiter_brevipes                no             1.0

# %%
endemicity.shape # Should be 9993 rows and 3 columns
# Out:
# (9993, 3)

# %% [markdown]
# **Formatting species names for consistent merging**

# %%
data["Species3"] = (
    data["Species3"]
    .str.strip()
    .str.replace(" ", "_", regex=False)
)

# %%
data = data.merge(
    endemicity,
    left_on="Species3",
    right_on="species",
    how="left"
)

# %%
data = data.drop(columns=["species"])

# %%
data.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'log_Beak.Length_Culmen',
#        'log_Beak.Width', 'log_Beak.Depth', 'log_Tarsus.Length',
#        'log_Wing.Length', 'log_Kipps.Distance', 'log_Tail.Length', 'log_Mass',
#        'Island_Endemicity', 'Flight_Ability'],
#       dtype='object')

# %%
data.shape # Should be 9980 rows and 13 columns
# Out:
# (9980, 13)

# %%
data[["Flight_Ability", "Island_Endemicity"]].isna().any() # Should be False
# Out:
# Flight_Ability       False
# Island_Endemicity    False
# dtype: bool

# %% [markdown]
# ## 1.3 Incorporation of foraging strategy and sea bird category
#
# Foraging strategy and sea bird information were imported from an external AVONET-derived dataset and integrated with the main trait database for downstream analyses.

# %%
url = "https://raw.githubusercontent.com/martinezrubio/ECOTREX/main/data/raw/AVONET_fly_swim_walk_seabird.xlsx"
foraging = pd.read_excel(url)
foraging.head()
# Out:
#                     Species    fly  swim  walk seabird
# 0         Abeillia_abeillei  100.0   0.0   0.0      no
# 1    Abroscopus_albogularis   55.0   0.0  45.0      no
# 2    Abroscopus_schisticeps   60.0   0.0  40.0      no
# 3  Abroscopus_superciliaris   60.0   0.0  40.0      no
# 4            Aburria_aburri   50.0   0.0  50.0      no

# %%
foraging.shape # Should be 9981 rows and 5 columns
# Out:
# (9981, 5)

# %% [markdown]
# **Formatting species names for consistent merging**

# %%
data = data.merge(
    foraging,
    left_on="Species3",
    right_on="Species",
    how="left"
)

# %%
data = data.drop(columns="Species")

# %%
data.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'log_Beak.Length_Culmen',
#        'log_Beak.Width', 'log_Beak.Depth', 'log_Tarsus.Length',
#        'log_Wing.Length', 'log_Kipps.Distance', 'log_Tail.Length', 'log_Mass',
#        'Island_Endemicity', 'Flight_Ability', 'fly', 'swim', 'walk',
#        'seabird'],
#       dtype='object')

# %%
data.shape # Should be 9980 rows and 17 columns
# Out:
# (9980, 17)

# %%
data[["fly", "swim", "walk", "seabird"]].isna().any() # Should be False
# Out:
# fly        False
# swim       False
# walk       False
# seabird    False
# dtype: bool

# %% [markdown]
# ## 1.4 Incorporation of diet category
#
# Diet categories information were imported from AVONICHE and integrated with the main trait database for downstream analyses.

# %%
url = "https://raw.githubusercontent.com/martinezrubio/ECOTREX/main/data/raw/AVONICHE_2026.csv"
diet = pd.read_csv(url)
diet.head()
# Out:
#                 Species3       Family3           Order3        Avibase_id  \
# 0  Accipiter albogularis  Accipitridae  Accipitriformes  AVIBASE-BBB59880
# 1       Accipiter badius  Accipitridae  Accipitriformes  AVIBASE-1A0ECB6E
# 2      Accipiter bicolor  Accipitridae  Accipitriformes  AVIBASE-ADBE44E1
# 3   Accipiter brachyurus  Accipitridae  Accipitriformes  AVIBASE-68BF920B
# 4     Accipiter brevipes  Accipitridae  Accipitriformes  AVIBASE-8492E4B7
#
#    Inferred MainDiet   MainNiche  Pa  Pt  Ne  ...  APG  APS  APD  VAE  VAS  \
# 0         0       Vt         VPE   0   0   0  ...    0    0    0   30    0
# 1         0       Vt         VPE   0   0   0  ...    0    0    0    9    0
# 2         0       Vt         VPE   0   0   0  ...    0    0    0   40    0
# 3         0       Vt         VPE   0   0   0  ...    0    0    0   30    0
# 4         0       Vt  Generalist   0   0   0  ...    0    0    0    6   36
#
#    VPE  VGE  VGG  CAQ  CGR
# 0   70    0    0    0    0
# 1   72    9    0    0    0
# 2   60    0    0    0    0
# 3   70    0    0    0    0
# 4   18    0    0    0    0
#
# [5 rows x 48 columns]

# %%
diet.shape # Should be 9993 rows and 48 columns
# Out:
# (9993, 48)

# %%
diet.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'Avibase_id', 'Inferred', 'MainDiet',
#        'MainNiche', 'Pa', 'Pt', 'Ne', 'Se', 'Fr', 'In', 'Ap', 'Vt', 'Ca',
#        'PAG', 'PAS', 'PAD', 'PEL', 'PGR', 'NAE', 'NGL', 'SEL', 'SGR', 'FAE',
#        'FGL', 'FGR', 'IAE', 'ISA', 'ISS', 'ISG', 'IVS', 'IGE', 'IGG', 'APA',
#        'APL', 'APP', 'APG', 'APS', 'APD', 'VAE', 'VAS', 'VPE', 'VGE', 'VGG',
#        'CAQ', 'CGR'],
#       dtype='object')

# %% [markdown]
# **Selecting diet variables**

# %%
diet_vars = [
    "MainDiet","MainNiche",
    "Pa", "Pt", "Ne", "Se", "Fr", "In", "Ap", "Vt", "Ca",
    "PAG", "PAS", "PAD", "PEL", "PGR", "NAE", "NGL", "SEL", "SGR", "FAE",
    "FGL", "FGR", "IAE", "ISA", "ISS", "ISG", "IVS", "IGE", "IGG", "APA",
    "APL", "APP", "APG", "APS", "APD", "VAE", "VAS", "VPE", "VGE", "VGG",
    "CAQ", "CGR"
]

# %% [markdown]
# **Formatting species names for consistent merging**

# %%
diet["Species3"] = (
    diet["Species3"]
    .str.strip()
    .str.replace(" ", "_", regex=False)
)

# %%
diet_sub = diet[["Species3"] + diet_vars]

# %%
data = data.merge(
    diet_sub,
    left_on="Species3",
    right_on="Species3",
    how="left"
)

# %%
data.columns
# Out:
# Index(['Species3', 'Family3', 'Order3', 'log_Beak.Length_Culmen',
#        'log_Beak.Width', 'log_Beak.Depth', 'log_Tarsus.Length',
#        'log_Wing.Length', 'log_Kipps.Distance', 'log_Tail.Length', 'log_Mass',
#        'Island_Endemicity', 'Flight_Ability', 'fly', 'swim', 'walk', 'seabird',
#        'MainDiet', 'MainNiche', 'Pa', 'Pt', 'Ne', 'Se', 'Fr', 'In', 'Ap', 'Vt',
#        'Ca', 'PAG', 'PAS', 'PAD', 'PEL', 'PGR', 'NAE', 'NGL', 'SEL', 'SGR',
#        'FAE', 'FGL', 'FGR', 'IAE', 'ISA', 'ISS', 'ISG', 'IVS', 'IGE', 'IGG',
#        'APA', 'APL', 'APP', 'APG', 'APS', 'APD', 'VAE', 'VAS', 'VPE', 'VGE',
#        'VGG', 'CAQ', 'CGR'],
#       dtype='object')

# %%
data.shape # Should be 9980 rows and 60 columns
# Out:
# (9980, 60)

# %% [markdown]
# **Renaming columns**

# %%
data = data.rename(columns={
    "Species3": "Species",
    "Family3": "Family",
    "Order3": "Order",
    "MainDiet": "dn.cat",
    "MainNiche": "fd.cat"
})

# %%
diet_map = {
    "In": "Invertivore",
    "Ap": "Aquatic_predator",
    "Vt": "Vertivore",
    "Ne": "Nectarivore",
    "Fr": "Frugivore",
    "Se": "Granivore",
    "Pa": "Aquatic_Herbivore",
    "Pt": "Terrestrial_Herbivore",
    "Ca" : "Scavenger",
    "Omnivore" : "Omnivore"
}

# %%
data["diet_simple"] = data["dn.cat"].map(diet_map)

# %%
data[["dn.cat", "diet_simple"]].value_counts(dropna=False)
# Out:
# dn.cat    diet_simple
# In        Invertivore              4782
# Omnivore  Omnivore                 1732
# Fr        Frugivore                1030
# Ap        Aquatic_predator          757
# Se        Granivore                 664
# Ne        Nectarivore               507
# Vt        Vertivore                 311
# Pt        Terrestrial_Herbivore      93
# Pa        Aquatic_Herbivore          82
# Ca        Scavenger                  22
# Name: count, dtype: int64

# %% [markdown]
# ### 1.4.1 Reclassification of scavenger diets into vertebrate-based feeding categories
#
# Carrion-based diet category (Ca) was merged into vertebrate-based feeding category (Vt) by redistributing proportional values and recoding dominant diet labels, ensuring consistency across diet representations.

# %%
data["Vt"] = data["Vt"] + data["Ca"]

# %%
data = data.drop(columns=["Ca"])

# %%
"Ca" in data.columns # Should be False
# Out:
# False

# %% [markdown]
# **Validation of diet proportion consistency**
#
# Diet proportions were verified to ensure that the redistribution preserved the total dietary composition, with proportions summing to 100% for each species.

# %%
diet_cols = ["Pa", "Pt", "Ne", "Se", "Fr", "In", "Ap", "Vt"]

# %%
(data[diet_cols].sum(axis=1).round(5) == 100).all() # Should be True
# Out:
# True

# %% [markdown]
# **Inspection of scavenger species diet profiles**
#
# Species previously classified as scavengers were inspected to confirm the redistribution of diet proportions, and to see if they were all classified to Vt.

# %%
diet_cols = ["Pa", "Pt", "Ne", "Se", "Fr", "In", "Ap", "Vt"]

# %%
cols_to_show = ["Species"] + diet_cols

# %%
scavengers = data.loc[data["dn.cat"] == "Ca", cols_to_show]

# %%
scavengers.head()
# Out:
#                Species  Pa  Pt  Ne  Se  Fr  In  Ap   Vt
# 50   Aegypius_monachus   0   0   0   0   0   0   0  100
# 142  Gypaetus_barbatus   0   0   0   0   0   0   0  100
# 144     Gyps_africanus   0   0   0   0   0   0   0  100
# 145   Gyps_bengalensis   0   0   0   0   0   0   0  100
# 146   Gyps_coprotheres   0   0   0   0   0   0   0  100

# %% [markdown]
# **Reclassification of dominant diet category**
#
# The dominant diet category was updated by recoding carrion-based diets (Ca) as vertebrate-based diets (Vt).

# %%
data["dn.cat"] = data["dn.cat"].replace({"Ca": "Vt"})

# %%
data["dn.cat"].value_counts()
# Out:
# dn.cat
# In          4782
# Omnivore    1732
# Fr          1030
# Ap           757
# Se           664
# Ne           507
# Vt           333
# Pt            93
# Pa            82
# Name: count, dtype: int64

# %% [markdown]
# **Harmonization of simplified diet categories**
#
# Simplified diet categories were updated to reflect the removal of scavenger diets, reclassifying them as vertebrate-based diets.

# %%
data["diet_simple"] = data["diet_simple"].replace({"Scavenger": "Vertivore"})

# %%
data["diet_simple"].value_counts()
# Out:
# diet_simple
# Invertivore              4782
# Omnivore                 1732
# Frugivore                1030
# Aquatic_predator          757
# Granivore                 664
# Nectarivore               507
# Vertivore                 333
# Terrestrial_Herbivore      93
# Aquatic_Herbivore          82
# Name: count, dtype: int64

# %% [markdown]
# ## 1.5 Phylogenetic PCA and integration of evolutionary information
#
# Phylogenetic structure was accounted for by computing a Brownian-motion variance–covariance matrix from an avian phylogeny and extracting the first 12 phylogenetic principal components. These components summarize shared evolutionary history and were merged with the main dataset at the species level.

# %% [markdown]
# **Install R and rpy2**

# %%
# !pip install biopython openpyxl
from Bio import Phylo
import openpyxl
from io import StringIO
import requests
# Out:
# Requirement already satisfied: biopython in /Users/nataliamartinezrubio/anaconda3/lib/python3.11/site-packages (1.86)
# Requirement already satisfied: openpyxl in /Users/nataliamartinezrubio/anaconda3/lib/python3.11/site-packages (3.0.10)
# Requirement already satisfied: numpy in /Users/nataliamartinezrubio/anaconda3/lib/python3.11/site-packages (from biopython) (1.24.3)
# Requirement already satisfied: et_xmlfile in /Users/nataliamartinezrubio/anaconda3/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
url = "https://raw.githubusercontent.com/martinezrubio/ECOTREX/main/data/raw/ecotrex_tree.nwk"
tree_str = requests.get(url).text
tree = Phylo.read(StringIO(tree_str), "newick")

# %%
conda install -c conda-forge rpy2 r-base r-essentials
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): | WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.11.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/nataliamartinezrubio/anaconda3
#
#   added / updated specs:
#     - r-base
#     - r-essentials
#     - rpy2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _r-mutex-1.0.1             |      anacondar_1           3 KB  conda-forge
#     anaconda-cloud-auth-0.5.0  |     pyhd8ed1ab_1          25 KB  conda-forge
#     boost-cpp-1.81.0           |       hf96b251_0        15.1 MB  conda-forge
#     bwidget-1.10.1             |       hce30654_1         127 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     cairo-1.16.0               |    h73a0509_1014         1.3 MB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     clang-14.0.6               |       hce30654_0         127 KB  conda-forge
#     clang-14-14.0.6            |default_h81a5282_0         961 KB  conda-forge
#     clang_osx-arm64-14.0.6     |       h15773ab_6          20 KB  conda-forge
#     clangxx-14.0.6             |default_hb7ecf47_0         127 KB  conda-forge
#     clangxx_osx-arm64-14.0.6   |       he29aa18_6          19 KB  conda-forge
#     compiler-rt-14.0.6         |       h30b49de_0          83 KB  conda-forge
#     compiler-rt_osx-arm64-14.0.6|       h48302dc_0        15.1 MB  conda-forge
#     conda-23.7.4               |  py311h267d04e_0         1.3 MB  conda-forge
#     expat-2.7.3                |       haf25636_0         128 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h82840c6_0         232 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |       hc364b38_1           4 KB  conda-forge
#     fribidi-1.0.16             |       hc919400_0          58 KB  conda-forge
#     gettext-0.21.1             |       h0186832_0         3.8 MB  conda-forge
#     gfortran_impl_osx-arm64-11.0.1.dev0|      hbce66ab_23        18.7 MB  conda-forge
#     gfortran_osx-arm64-11.0.1.dev0|      h57527a5_15          22 KB  conda-forge
#     glib-2.76.1                |       hb5ab8b9_0         471 KB  conda-forge
#     glib-tools-2.76.1          |       hb5ab8b9_0          96 KB  conda-forge
#     graphite2-1.3.13           |    h9f76cd9_1001          81 KB  conda-forge
#     gsl-2.7                    |       h6e638da_0         2.6 MB  conda-forge
#     gst-plugins-base-1.22.0    |       h8b7775e_2         1.8 MB  conda-forge
#     gstreamer-1.22.0           |       hcb7b3dd_2         1.3 MB  conda-forge
#     harfbuzz-6.0.0             |       hddbc195_0         1.1 MB  conda-forge
#     icu-70.1                   |       h6b3803e_0        13.3 MB  conda-forge
#     isl-0.22.1                 |       hb904e53_2         748 KB  conda-forge
#     libblas-3.9.0              |16_osxarm64_openblas          13 KB  conda-forge
#     libcblas-3.9.0             |16_osxarm64_openblas          13 KB  conda-forge
#     libclang-cpp14-14.0.6      |default_h81a5282_0        13.1 MB  conda-forge
#     libexpat-2.7.3             |       haf25636_0          66 KB  conda-forge
#     libgfortran-devel_osx-arm64-11.0.1.dev0|      hf114ba7_23         257 KB  conda-forge
#     libglib-2.76.1             |       h4646484_0         2.3 MB  conda-forge
#     libiconv-1.18              |       h23cfdf5_2         733 KB  conda-forge
#     liblapack-3.9.0            |16_osxarm64_openblas          13 KB  conda-forge
#     libogg-1.3.5               |       h48c0fde_1         212 KB  conda-forge
#     libopus-1.6.1              |       h1a92334_0         301 KB  conda-forge
#     libpq-15.3                 |       h7126958_1         2.3 MB  conda-forge
#     libsolv-0.7.24             |       hb5ab8b9_0         377 KB  conda-forge
#     libsqlite-3.46.0           |       hfb93653_0         811 KB  conda-forge
#     libvorbis-1.3.7            |       h9f76cd9_0         249 KB  conda-forge
#     libxml2-2.10.3             |       h67585b2_4         584 KB  conda-forge
#     libxslt-1.1.37             |       h1bd8bc4_0         231 KB  conda-forge
#     libzlib-1.2.13             |       hfb2fe0b_6          46 KB  conda-forge
#     llvm-tools-14.0.6          |       hfd8c8a6_3        10.4 MB
#     lxml-4.9.2                 |  py311h246f609_0         1.2 MB  conda-forge
#     make-4.4.1                 |       hc9fafa5_2         268 KB  conda-forge
#     mysql-common-8.0.32        |       h518ea0a_1         744 KB  conda-forge
#     mysql-libs-8.0.32          |       hcb599eb_1         1.4 MB  conda-forge
#     nspr-4.35                  |       hb7217d7_0         216 KB  conda-forge
#     nss-3.89                   |       h789eff7_0         1.7 MB  conda-forge
#     openssl-3.1.8              |       h81ee809_0         2.1 MB  conda-forge
#     pandoc-3.8.3               |       hce30654_0        27.2 MB  conda-forge
#     pango-1.50.14              |       h6c112b8_0         400 KB  conda-forge
#     pcre2-10.40                |       hb34f9b4_0         1.1 MB  conda-forge
#     pixman-0.40.0              |       h27ca646_0         285 KB  conda-forge
#     python-3.11.5              |h47c9636_0_cpython        14.0 MB  conda-forge
#     python_abi-3.11            |          8_cp311           7 KB  conda-forge
#     qt-main-5.15.8             |       hfe8d25c_6        48.3 MB  conda-forge
#     qtwebkit-5.212             |       hbfb98c5_8         9.6 MB  conda-forge
#     r-askpass-1.2.0            |    r42h21dc0da_0          31 KB  conda-forge
#     r-assertthat-0.2.1         |    r42hc72bb7e_4          70 KB  conda-forge
#     r-backports-1.5.0          |    r42h07cda29_0         126 KB  conda-forge
#     r-base-4.2.2               |       heabe65b_3        24.8 MB  conda-forge
#     r-base64enc-0.1_3          | r42h21dc0da_1006          44 KB  conda-forge
#     r-bit-4.0.5                |    r42h21dc0da_1         1.0 MB  conda-forge
#     r-bit64-4.0.5              |    r42h21dc0da_2         470 KB  conda-forge
#     r-blob-1.2.4               |    r42hc72bb7e_1          65 KB  conda-forge
#     r-boot-1.3_30              |    r42hc72bb7e_0         616 KB  conda-forge
#     r-broom-1.0.6              |    r42hc72bb7e_0         1.7 MB  conda-forge
#     r-bslib-0.5.1              |    r42hc72bb7e_0         4.8 MB  conda-forge
#     r-cachem-1.1.0             |    r42h07cda29_0          73 KB  conda-forge
#     r-callr-3.7.6              |    r42hc72bb7e_0         414 KB  conda-forge
#     r-caret-6.0_94             |    r42h21dc0da_1         3.4 MB  conda-forge
#     r-cellranger-1.1.0         | r42hc72bb7e_1006         107 KB  conda-forge
#     r-class-7.3_22             |    r42h21dc0da_1         103 KB  conda-forge
#     r-cli-3.6.1                |    r42h9a38a31_0         1.2 MB  conda-forge
#     r-clipr-0.8.0              |    r42hc72bb7e_2          67 KB  conda-forge
#     r-clock-0.6.1              |    r42h9a38a31_1         2.0 MB  conda-forge
#     r-cluster-2.1.4            |    r42h505ec0b_0         576 KB  conda-forge
#     r-codetools-0.2_20         |    r42hc72bb7e_0         106 KB  conda-forge
#     r-colorspace-2.1_0         |    r42h21dc0da_1         2.4 MB  conda-forge
#     r-commonmark-1.9.1         |    r42hd2d937b_0         116 KB  conda-forge
#     r-cpp11-0.5.2              |    r42hc72bb7e_0         229 KB  conda-forge
#     r-crayon-1.5.3             |    r42hc72bb7e_0         164 KB  conda-forge
#     r-crul-1.4.2               |    r42h785f33e_0         620 KB  conda-forge
#     r-curl-5.0.2               |    r42h867807f_0         442 KB  conda-forge
#     r-data.table-1.14.4        |    r42h5b9a8e2_0         1.9 MB  conda-forge
#     r-dbi-1.2.3                |    r42hc72bb7e_0         825 KB  conda-forge
#     r-dbplyr-2.4.0             |    r42hc72bb7e_0         1.1 MB  conda-forge
#     r-diagram-1.6.5            |    r42ha770c72_2         655 KB  conda-forge
#     r-digest-0.6.31            |    r42h9a38a31_0         175 KB  conda-forge
#     r-dplyr-1.1.1              |    r42h9a38a31_0         1.3 MB  conda-forge
#     r-dtplyr-1.3.1             |    r42hc72bb7e_1         350 KB  conda-forge
#     r-e1071-1.7_13             |    r42h9a38a31_0         569 KB  conda-forge
#     r-ellipsis-0.3.2           |    r42h21dc0da_2          42 KB  conda-forge
#     r-essentials-4.2           | r42hd8ed1ab_2004           8 KB  conda-forge
#     r-evaluate-0.24.0          |    r42hc72bb7e_0          91 KB  conda-forge
#     r-fansi-1.0.6              |    r42hd2d937b_0         303 KB  conda-forge
#     r-farver-2.1.1             |    r42h9a38a31_1         1.4 MB  conda-forge
#     r-fastmap-1.1.1            |    r42h9a38a31_0          68 KB  conda-forge
#     r-fontawesome-0.5.2        |    r42hc72bb7e_0         1.2 MB  conda-forge
#     r-forcats-1.0.0            |    r42hc72bb7e_1         414 KB  conda-forge
#     r-foreach-1.5.2            |    r42hc72bb7e_2         135 KB  conda-forge
#     r-foreign-0.8_87           |    r42h07cda29_0         256 KB  conda-forge
#     r-formatr-1.14             |    r42hc72bb7e_1         162 KB  conda-forge
#     r-fs-1.6.1                 |    r42h9a38a31_0         266 KB  conda-forge
#     r-future-1.33.2            |    r42h785f33e_0         614 KB  conda-forge
#     r-future.apply-1.11.2      |    r42hc72bb7e_0         162 KB  conda-forge
#     r-gargle-1.5.2             |    r42h785f33e_0         692 KB  conda-forge
#     r-generics-0.1.3           |    r42hc72bb7e_2          89 KB  conda-forge
#     r-ggplot2-3.5.1            |    r42hc72bb7e_0         4.5 MB  conda-forge
#     r-gistr-0.9.0              |    r42hc72bb7e_2         755 KB  conda-forge
#     r-glmnet-4.1_2             |    r42h505ec0b_1         1.8 MB  conda-forge
#     r-globals-0.16.3           |    r42hc72bb7e_0         121 KB  conda-forge
#     r-glue-1.7.0               |    r42hd2d937b_0         152 KB  conda-forge
#     r-googledrive-2.1.1        |    r42hc72bb7e_1         1.1 MB  conda-forge
#     r-googlesheets4-1.1.1      |    r42h785f33e_1         504 KB  conda-forge
#     r-gower-1.0.1              |    r42h21dc0da_1         218 KB  conda-forge
#     r-gtable-0.3.5             |    r42hc72bb7e_0         217 KB  conda-forge
#     r-hardhat-1.4.0            |    r42hc72bb7e_0         791 KB  conda-forge
#     r-haven-2.5.2              |    r42h9a38a31_0         334 KB  conda-forge
#     r-hexbin-1.28.2            |    r42h505ec0b_1         1.5 MB  conda-forge
#     r-highr-0.11               |    r42hc72bb7e_0          55 KB  conda-forge
#     r-hms-1.1.3                |    r42hc72bb7e_1         104 KB  conda-forge
#     r-htmltools-0.5.5          |    r42h9a38a31_0         346 KB  conda-forge
#     r-htmlwidgets-1.6.4        |    r42hc72bb7e_0         415 KB  conda-forge
#     r-httpcode-0.3.0           |    r42hf450f58_3          40 KB  conda-forge
#     r-httpuv-1.6.9             |    r42h9a38a31_0         521 KB  conda-forge
#     r-httr-1.4.7               |    r42hc72bb7e_0         460 KB  conda-forge
#     r-ids-1.0.1                |    r42hc72bb7e_3         124 KB  conda-forge
#     r-ipred-0.9_14             |    r42h21dc0da_1         384 KB  conda-forge
#     r-irdisplay-1.1            |    r42hd8ed1ab_2          38 KB  conda-forge
#     r-irkernel-1.3.2           |    r42h785f33e_1         226 KB  conda-forge
#     r-isoband-0.2.7            |    r42h9a38a31_1         1.5 MB  conda-forge
#     r-iterators-1.0.14         |    r42hc72bb7e_2         341 KB  conda-forge
#     r-jquerylib-0.1.4          |    r42hc72bb7e_2         299 KB  conda-forge
#     r-jsonlite-1.8.8           |    r42hd2d937b_0         617 KB  conda-forge
#     r-kernsmooth-2.23_20       |    r42h0419871_1         100 KB  conda-forge
#     r-knitr-1.42               |    r42hc72bb7e_1         1.2 MB  conda-forge
#     r-labeling-0.4.3           |    r42hc72bb7e_0          67 KB  conda-forge
#     r-later-1.3.0              |    r42h9a38a31_1         111 KB  conda-forge
#     r-lattice-0.22_6           |    r42hd2d937b_0         1.3 MB  conda-forge
#     r-lava-1.7.3               |    r42hc72bb7e_0         2.4 MB  conda-forge
#     r-lazyeval-0.2.2           |    r42h21dc0da_4         155 KB  conda-forge
#     r-lifecycle-1.0.4          |    r42hc72bb7e_0         120 KB  conda-forge
#     r-listenv-0.9.1            |    r42hc72bb7e_0         118 KB  conda-forge
#     r-lobstr-1.1.2             |    r42h9a38a31_2         134 KB  conda-forge
#     r-lubridate-1.9.3          |    r42h21dc0da_0         949 KB  conda-forge
#     r-magrittr-2.0.3           |    r42h21dc0da_2         203 KB  conda-forge
#     r-maps-3.4.2               |    r42hd2d937b_0         2.3 MB  conda-forge
#     r-mass-7.3_60.0.1          |    r42hd2d937b_0         1.1 MB  conda-forge
#     r-matrix-1.6_5             |    r42hb447869_0         3.6 MB  conda-forge
#     r-memoise-2.0.1            |    r42hc72bb7e_2          55 KB  conda-forge
#     r-mgcv-1.8_41              |    r42hc857ecf_0         3.1 MB  conda-forge
#     r-mime-0.12                |    r42h21dc0da_2          52 KB  conda-forge
#     r-modelmetrics-1.2.2.2     |    r42hf53d927_2         159 KB  conda-forge
#     r-modelr-0.1.11            |    r42hc72bb7e_1         215 KB  conda-forge
#     r-munsell-0.5.1            |    r42hc72bb7e_0         241 KB  conda-forge
#     r-nlme-3.1_162             |    r42h505ec0b_0         2.2 MB  conda-forge
#     r-nnet-7.3_19              |    r42h21dc0da_1         127 KB  conda-forge
#     r-numderiv-2016.8_1.1      |    r42hc72bb7e_5         125 KB  conda-forge
#     r-openssl-2.1.1            |    r42h138cb08_0         670 KB  conda-forge
#     r-parallelly-1.37.1        |    r42hd2d937b_0         361 KB  conda-forge
#     r-pbdzmq-0.3_9             |    r42hd9ec729_0         512 KB  conda-forge
#     r-pillar-1.9.0             |    r42hc72bb7e_1         603 KB  conda-forge
#     r-pkgconfig-2.0.3          |    r42hc72bb7e_3          26 KB  conda-forge
#     r-plyr-1.8.8               |    r42h9a38a31_0         836 KB  conda-forge
#     r-prettyunits-1.2.0        |    r42hc72bb7e_0         159 KB  conda-forge
#     r-proc-1.18.0              |    r42h9a38a31_1         851 KB  conda-forge
#     r-processx-3.8.4           |    r42hd2d937b_0         305 KB  conda-forge
#     r-prodlim-2023.03.31       |    r42h9a38a31_0         421 KB  conda-forge
#     r-progress-1.2.3           |    r42hc72bb7e_0          92 KB  conda-forge
#     r-progressr-0.14.0         |    r42hc72bb7e_0         342 KB  conda-forge
#     r-promises-1.2.0.1         |    r42h9a38a31_1         1.6 MB  conda-forge
#     r-proxy-0.4_27             |    r42h21dc0da_2         179 KB  conda-forge
#     r-pryr-0.1.6               |    r42h9a38a31_0         199 KB  conda-forge
#     r-ps-1.7.6                 |    r42hd2d937b_0         300 KB  conda-forge
#     r-purrr-1.0.2              |    r42h21dc0da_0         476 KB  conda-forge
#     r-quantmod-0.4.26          |    r42hc72bb7e_0        1020 KB  conda-forge
#     r-r6-2.5.1                 |    r42hc72bb7e_2          88 KB  conda-forge
#     r-randomforest-4.7_1.1     |    r42h505ec0b_1         236 KB  conda-forge
#     r-rappdirs-0.3.3           |    r42h21dc0da_2          51 KB  conda-forge
#     r-rbokeh-0.5.2             |    r42hc72bb7e_3         1.2 MB  conda-forge
#     r-rcolorbrewer-1.1_3       |    r42h785f33e_2          67 KB  conda-forge
#     r-rcpp-1.0.10              |    r42h9a38a31_0         1.9 MB  conda-forge
#     r-readr-2.1.4              |    r42h9a38a31_0         717 KB  conda-forge
#     r-readxl-1.4.2             |    r42h815e8a2_0         708 KB  conda-forge
#     r-recipes-1.0.10           |    r42hc72bb7e_0         1.5 MB  conda-forge
#     r-recommended-4.2          | r42hd8ed1ab_1006          18 KB  conda-forge
#     r-rematch-2.0.0            |    r42hc72bb7e_0          24 KB  conda-forge
#     r-rematch2-2.1.2           |    r42hc72bb7e_3          53 KB  conda-forge
#     r-repr-1.1.7               |    r42h785f33e_0         141 KB  conda-forge
#     r-reprex-2.1.0             |    r42hc72bb7e_0         488 KB  conda-forge
#     r-reshape2-1.4.4           |    r42h9a38a31_2         126 KB  conda-forge
#     r-rlang-1.1.0              |    r42h9a38a31_0         1.5 MB  conda-forge
#     r-rmarkdown-2.27           |    r42hc72bb7e_0         2.0 MB  conda-forge
#     r-rpart-4.1.23             |    r42hd2d937b_0         680 KB  conda-forge
#     r-rstudioapi-0.16.0        |    r42hc72bb7e_0         300 KB  conda-forge
#     r-rvest-1.0.4              |    r42hc72bb7e_0         292 KB  conda-forge
#     r-sass-0.4.5               |    r42h9a38a31_0         2.0 MB  conda-forge
#     r-scales-1.3.0             |    r42hc72bb7e_0         644 KB  conda-forge
#     r-selectr-0.4_2            |    r42hc72bb7e_3         411 KB  conda-forge
#     r-shape-1.4.6.1            |    r42ha770c72_0         744 KB  conda-forge
#     r-shiny-1.8.1.1            |    r42h785f33e_0         3.5 MB  conda-forge
#     r-sourcetools-0.1.7_1      |    r42h9a38a31_0          50 KB  conda-forge
#     r-spatial-7.3_17           |    r42h21dc0da_0         149 KB  conda-forge
#     r-squarem-2021.1           |    r42hc72bb7e_2         190 KB  conda-forge
#     r-stringi-1.7.12           |    r42ha4a7437_0         820 KB  conda-forge
#     r-stringr-1.5.1            |    r42h785f33e_0         289 KB  conda-forge
#     r-survival-3.7_0           |    r42h07cda29_0         6.0 MB  conda-forge
#     r-sys-3.4.2                |    r42h21dc0da_1          47 KB  conda-forge
#     r-tibble-3.2.1             |    r42h21dc0da_2         597 KB  conda-forge
#     r-tidyr-1.3.0              |    r42h9a38a31_0         1.1 MB  conda-forge
#     r-tidyselect-1.2.1         |    r42hc72bb7e_0         211 KB  conda-forge
#     r-tidyverse-1.3.2          |    r42hc72bb7e_1         438 KB  conda-forge
#     r-timechange-0.2.0         |    r42h9a38a31_0         174 KB  conda-forge
#     r-timedate-4032.109        |    r42hc72bb7e_0         1.2 MB  conda-forge
#     r-tinytex-0.51             |    r42hc72bb7e_0         145 KB  conda-forge
#     r-triebeard-0.4.1          |    r42h9a38a31_0         145 KB  conda-forge
#     r-ttr-0.24.4               |    r42hd2d937b_0         516 KB  conda-forge
#     r-tzdb-0.3.0               |    r42h9a38a31_1         521 KB  conda-forge
#     r-urltools-1.7.3           |    r42h9a38a31_3         285 KB  conda-forge
#     r-utf8-1.2.4               |    r42hd2d937b_0         136 KB  conda-forge
#     r-uuid-1.2_0               |    r42hd2d937b_0          51 KB  conda-forge
#     r-vctrs-0.6.1              |    r42h9a38a31_0         1.2 MB  conda-forge
#     r-viridislite-0.4.2        |    r42hc72bb7e_1         1.2 MB  conda-forge
#     r-vroom-1.6.1              |    r42h9a38a31_0         771 KB  conda-forge
#     r-withr-3.0.0              |    r42hc72bb7e_0         243 KB  conda-forge
#     r-xfun-0.38                |    r42h9a38a31_0         409 KB  conda-forge
#     r-xml2-1.3.3               |    r42haf93cbb_2         193 KB  conda-forge
#     r-xtable-1.8_4             |    r42hc72bb7e_5         682 KB  conda-forge
#     r-xts-0.14.0               |    r42h07cda29_0         744 KB  conda-forge
#     r-yaml-2.3.8               |    r42hd2d937b_0         103 KB  conda-forge
#     r-zoo-1.8_12               |    r42h21dc0da_1         981 KB  conda-forge
#     rpy2-3.5.11                |py311r42hb49d859_3         547 KB  conda-forge
#     semver-3.0.4               |     pyhcf101f3_1          22 KB  conda-forge
#     simplegeneric-0.8.1        |     pyhd8ed1ab_2          11 KB  conda-forge
#     tktable-2.10               |       hd996620_4          77 KB  conda-forge
#     tzlocal-5.3.1              |     pyh8f84b5b_0          23 KB  conda-forge
#     zlib-1.2.13                |       hfb2fe0b_6          76 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       366.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _r-mutex           conda-forge/noarch::_r-mutex-1.0.1-anacondar_1
#   bwidget            conda-forge/osx-arm64::bwidget-1.10.1-hce30654_1
#   cairo              conda-forge/osx-arm64::cairo-1.16.0-h73a0509_1014
#   clang              conda-forge/osx-arm64::clang-14.0.6-hce30654_0
#   clang-14           conda-forge/osx-arm64::clang-14-14.0.6-default_h81a5282_0
#   clang_osx-arm64    conda-forge/osx-arm64::clang_osx-arm64-14.0.6-h15773ab_6
#   clangxx            conda-forge/osx-arm64::clangxx-14.0.6-default_hb7ecf47_0
#   clangxx_osx-arm64  conda-forge/osx-arm64::clangxx_osx-arm64-14.0.6-he29aa18_6
#   compiler-rt        conda-forge/osx-arm64::compiler-rt-14.0.6-h30b49de_0
#   compiler-rt_osx-a~ conda-forge/noarch::compiler-rt_osx-arm64-14.0.6-h48302dc_0
#   expat              conda-forge/osx-arm64::expat-2.7.3-haf25636_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.14.2-h82840c6_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
#   fribidi            conda-forge/osx-arm64::fribidi-1.0.16-hc919400_0
#   gfortran_impl_osx~ conda-forge/osx-arm64::gfortran_impl_osx-arm64-11.0.1.dev0-hbce66ab_23
#   gfortran_osx-arm64 conda-forge/osx-arm64::gfortran_osx-arm64-11.0.1.dev0-h57527a5_15
#   glib-tools         conda-forge/osx-arm64::glib-tools-2.76.1-hb5ab8b9_0
#   graphite2          conda-forge/osx-arm64::graphite2-1.3.13-h9f76cd9_1001
#   gsl                conda-forge/osx-arm64::gsl-2.7-h6e638da_0
#   harfbuzz           conda-forge/osx-arm64::harfbuzz-6.0.0-hddbc195_0
#   isl                conda-forge/osx-arm64::isl-0.22.1-hb904e53_2
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-16_osxarm64_openblas
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-16_osxarm64_openblas
#   libclang-cpp14     conda-forge/osx-arm64::libclang-cpp14-14.0.6-default_h81a5282_0
#   libexpat           conda-forge/osx-arm64::libexpat-2.7.3-haf25636_0
#   libgfortran-devel~ conda-forge/noarch::libgfortran-devel_osx-arm64-11.0.1.dev0-hf114ba7_23
#   libglib            conda-forge/osx-arm64::libglib-2.76.1-h4646484_0
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-16_osxarm64_openblas
#   libogg             conda-forge/osx-arm64::libogg-1.3.5-h48c0fde_1
#   libopus            conda-forge/osx-arm64::libopus-1.6.1-h1a92334_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.46.0-hfb93653_0
#   libvorbis          conda-forge/osx-arm64::libvorbis-1.3.7-h9f76cd9_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.2.13-hfb2fe0b_6
#   llvm-tools         pkgs/main/osx-arm64::llvm-tools-14.0.6-hfd8c8a6_3
#   make               conda-forge/osx-arm64::make-4.4.1-hc9fafa5_2
#   mysql-common       conda-forge/osx-arm64::mysql-common-8.0.32-h518ea0a_1
#   mysql-libs         conda-forge/osx-arm64::mysql-libs-8.0.32-hcb599eb_1
#   nspr               conda-forge/osx-arm64::nspr-4.35-hb7217d7_0
#   nss                conda-forge/osx-arm64::nss-3.89-h789eff7_0
#   pandoc             conda-forge/osx-arm64::pandoc-3.8.3-hce30654_0
#   pango              conda-forge/osx-arm64::pango-1.50.14-h6c112b8_0
#   pixman             conda-forge/osx-arm64::pixman-0.40.0-h27ca646_0
#   python_abi         conda-forge/noarch::python_abi-3.11-8_cp311
#   r-askpass          conda-forge/osx-arm64::r-askpass-1.2.0-r42h21dc0da_0
#   r-assertthat       conda-forge/noarch::r-assertthat-0.2.1-r42hc72bb7e_4
#   r-backports        conda-forge/osx-arm64::r-backports-1.5.0-r42h07cda29_0
#   r-base             conda-forge/osx-arm64::r-base-4.2.2-heabe65b_3
#   r-base64enc        conda-forge/osx-arm64::r-base64enc-0.1_3-r42h21dc0da_1006
#   r-bit              conda-forge/osx-arm64::r-bit-4.0.5-r42h21dc0da_1
#   r-bit64            conda-forge/osx-arm64::r-bit64-4.0.5-r42h21dc0da_2
#   r-blob             conda-forge/noarch::r-blob-1.2.4-r42hc72bb7e_1
#   r-boot             conda-forge/noarch::r-boot-1.3_30-r42hc72bb7e_0
#   r-broom            conda-forge/noarch::r-broom-1.0.6-r42hc72bb7e_0
#   r-bslib            conda-forge/noarch::r-bslib-0.5.1-r42hc72bb7e_0
#   r-cachem           conda-forge/osx-arm64::r-cachem-1.1.0-r42h07cda29_0
#   r-callr            conda-forge/noarch::r-callr-3.7.6-r42hc72bb7e_0
#   r-caret            conda-forge/osx-arm64::r-caret-6.0_94-r42h21dc0da_1
#   r-cellranger       conda-forge/noarch::r-cellranger-1.1.0-r42hc72bb7e_1006
#   r-class            conda-forge/osx-arm64::r-class-7.3_22-r42h21dc0da_1
#   r-cli              conda-forge/osx-arm64::r-cli-3.6.1-r42h9a38a31_0
#   r-clipr            conda-forge/noarch::r-clipr-0.8.0-r42hc72bb7e_2
#   r-clock            conda-forge/osx-arm64::r-clock-0.6.1-r42h9a38a31_1
#   r-cluster          conda-forge/osx-arm64::r-cluster-2.1.4-r42h505ec0b_0
#   r-codetools        conda-forge/noarch::r-codetools-0.2_20-r42hc72bb7e_0
#   r-colorspace       conda-forge/osx-arm64::r-colorspace-2.1_0-r42h21dc0da_1
#   r-commonmark       conda-forge/osx-arm64::r-commonmark-1.9.1-r42hd2d937b_0
#   r-cpp11            conda-forge/noarch::r-cpp11-0.5.2-r42hc72bb7e_0
#   r-crayon           conda-forge/noarch::r-crayon-1.5.3-r42hc72bb7e_0
#   r-crul             conda-forge/noarch::r-crul-1.4.2-r42h785f33e_0
#   r-curl             conda-forge/osx-arm64::r-curl-5.0.2-r42h867807f_0
#   r-data.table       conda-forge/osx-arm64::r-data.table-1.14.4-r42h5b9a8e2_0
#   r-dbi              conda-forge/noarch::r-dbi-1.2.3-r42hc72bb7e_0
#   r-dbplyr           conda-forge/noarch::r-dbplyr-2.4.0-r42hc72bb7e_0
#   r-diagram          conda-forge/noarch::r-diagram-1.6.5-r42ha770c72_2
#   r-digest           conda-forge/osx-arm64::r-digest-0.6.31-r42h9a38a31_0
#   r-dplyr            conda-forge/osx-arm64::r-dplyr-1.1.1-r42h9a38a31_0
#   r-dtplyr           conda-forge/noarch::r-dtplyr-1.3.1-r42hc72bb7e_1
#   r-e1071            conda-forge/osx-arm64::r-e1071-1.7_13-r42h9a38a31_0
#   r-ellipsis         conda-forge/osx-arm64::r-ellipsis-0.3.2-r42h21dc0da_2
#   r-essentials       conda-forge/noarch::r-essentials-4.2-r42hd8ed1ab_2004
#   r-evaluate         conda-forge/noarch::r-evaluate-0.24.0-r42hc72bb7e_0
#   r-fansi            conda-forge/osx-arm64::r-fansi-1.0.6-r42hd2d937b_0
#   r-farver           conda-forge/osx-arm64::r-farver-2.1.1-r42h9a38a31_1
#   r-fastmap          conda-forge/osx-arm64::r-fastmap-1.1.1-r42h9a38a31_0
#   r-fontawesome      conda-forge/noarch::r-fontawesome-0.5.2-r42hc72bb7e_0
#   r-forcats          conda-forge/noarch::r-forcats-1.0.0-r42hc72bb7e_1
#   r-foreach          conda-forge/noarch::r-foreach-1.5.2-r42hc72bb7e_2
#   r-foreign          conda-forge/osx-arm64::r-foreign-0.8_87-r42h07cda29_0
#   r-formatr          conda-forge/noarch::r-formatr-1.14-r42hc72bb7e_1
#   r-fs               conda-forge/osx-arm64::r-fs-1.6.1-r42h9a38a31_0
#   r-future           conda-forge/noarch::r-future-1.33.2-r42h785f33e_0
#   r-future.apply     conda-forge/noarch::r-future.apply-1.11.2-r42hc72bb7e_0
#   r-gargle           conda-forge/noarch::r-gargle-1.5.2-r42h785f33e_0
#   r-generics         conda-forge/noarch::r-generics-0.1.3-r42hc72bb7e_2
#   r-ggplot2          conda-forge/noarch::r-ggplot2-3.5.1-r42hc72bb7e_0
#   r-gistr            conda-forge/noarch::r-gistr-0.9.0-r42hc72bb7e_2
#   r-glmnet           conda-forge/osx-arm64::r-glmnet-4.1_2-r42h505ec0b_1
#   r-globals          conda-forge/noarch::r-globals-0.16.3-r42hc72bb7e_0
#   r-glue             conda-forge/osx-arm64::r-glue-1.7.0-r42hd2d937b_0
#   r-googledrive      conda-forge/noarch::r-googledrive-2.1.1-r42hc72bb7e_1
#   r-googlesheets4    conda-forge/noarch::r-googlesheets4-1.1.1-r42h785f33e_1
#   r-gower            conda-forge/osx-arm64::r-gower-1.0.1-r42h21dc0da_1
#   r-gtable           conda-forge/noarch::r-gtable-0.3.5-r42hc72bb7e_0
#   r-hardhat          conda-forge/noarch::r-hardhat-1.4.0-r42hc72bb7e_0
#   r-haven            conda-forge/osx-arm64::r-haven-2.5.2-r42h9a38a31_0
#   r-hexbin           conda-forge/osx-arm64::r-hexbin-1.28.2-r42h505ec0b_1
#   r-highr            conda-forge/noarch::r-highr-0.11-r42hc72bb7e_0
#   r-hms              conda-forge/noarch::r-hms-1.1.3-r42hc72bb7e_1
#   r-htmltools        conda-forge/osx-arm64::r-htmltools-0.5.5-r42h9a38a31_0
#   r-htmlwidgets      conda-forge/noarch::r-htmlwidgets-1.6.4-r42hc72bb7e_0
#   r-httpcode         conda-forge/osx-arm64::r-httpcode-0.3.0-r42hf450f58_3
#   r-httpuv           conda-forge/osx-arm64::r-httpuv-1.6.9-r42h9a38a31_0
#   r-httr             conda-forge/noarch::r-httr-1.4.7-r42hc72bb7e_0
#   r-ids              conda-forge/noarch::r-ids-1.0.1-r42hc72bb7e_3
#   r-ipred            conda-forge/osx-arm64::r-ipred-0.9_14-r42h21dc0da_1
#   r-irdisplay        conda-forge/noarch::r-irdisplay-1.1-r42hd8ed1ab_2
#   r-irkernel         conda-forge/noarch::r-irkernel-1.3.2-r42h785f33e_1
#   r-isoband          conda-forge/osx-arm64::r-isoband-0.2.7-r42h9a38a31_1
#   r-iterators        conda-forge/noarch::r-iterators-1.0.14-r42hc72bb7e_2
#   r-jquerylib        conda-forge/noarch::r-jquerylib-0.1.4-r42hc72bb7e_2
#   r-jsonlite         conda-forge/osx-arm64::r-jsonlite-1.8.8-r42hd2d937b_0
#   r-kernsmooth       conda-forge/osx-arm64::r-kernsmooth-2.23_20-r42h0419871_1
#   r-knitr            conda-forge/noarch::r-knitr-1.42-r42hc72bb7e_1
#   r-labeling         conda-forge/noarch::r-labeling-0.4.3-r42hc72bb7e_0
#   r-later            conda-forge/osx-arm64::r-later-1.3.0-r42h9a38a31_1
#   r-lattice          conda-forge/osx-arm64::r-lattice-0.22_6-r42hd2d937b_0
#   r-lava             conda-forge/noarch::r-lava-1.7.3-r42hc72bb7e_0
#   r-lazyeval         conda-forge/osx-arm64::r-lazyeval-0.2.2-r42h21dc0da_4
#   r-lifecycle        conda-forge/noarch::r-lifecycle-1.0.4-r42hc72bb7e_0
#   r-listenv          conda-forge/noarch::r-listenv-0.9.1-r42hc72bb7e_0
#   r-lobstr           conda-forge/osx-arm64::r-lobstr-1.1.2-r42h9a38a31_2
#   r-lubridate        conda-forge/osx-arm64::r-lubridate-1.9.3-r42h21dc0da_0
#   r-magrittr         conda-forge/osx-arm64::r-magrittr-2.0.3-r42h21dc0da_2
#   r-maps             conda-forge/osx-arm64::r-maps-3.4.2-r42hd2d937b_0
#   r-mass             conda-forge/osx-arm64::r-mass-7.3_60.0.1-r42hd2d937b_0
#   r-matrix           conda-forge/osx-arm64::r-matrix-1.6_5-r42hb447869_0
#   r-memoise          conda-forge/noarch::r-memoise-2.0.1-r42hc72bb7e_2
#   r-mgcv             conda-forge/osx-arm64::r-mgcv-1.8_41-r42hc857ecf_0
#   r-mime             conda-forge/osx-arm64::r-mime-0.12-r42h21dc0da_2
#   r-modelmetrics     conda-forge/osx-arm64::r-modelmetrics-1.2.2.2-r42hf53d927_2
#   r-modelr           conda-forge/noarch::r-modelr-0.1.11-r42hc72bb7e_1
#   r-munsell          conda-forge/noarch::r-munsell-0.5.1-r42hc72bb7e_0
#   r-nlme             conda-forge/osx-arm64::r-nlme-3.1_162-r42h505ec0b_0
#   r-nnet             conda-forge/osx-arm64::r-nnet-7.3_19-r42h21dc0da_1
#   r-numderiv         conda-forge/noarch::r-numderiv-2016.8_1.1-r42hc72bb7e_5
#   r-openssl          conda-forge/osx-arm64::r-openssl-2.1.1-r42h138cb08_0
#   r-parallelly       conda-forge/osx-arm64::r-parallelly-1.37.1-r42hd2d937b_0
#   r-pbdzmq           conda-forge/osx-arm64::r-pbdzmq-0.3_9-r42hd9ec729_0
#   r-pillar           conda-forge/noarch::r-pillar-1.9.0-r42hc72bb7e_1
#   r-pkgconfig        conda-forge/noarch::r-pkgconfig-2.0.3-r42hc72bb7e_3
#   r-plyr             conda-forge/osx-arm64::r-plyr-1.8.8-r42h9a38a31_0
#   r-prettyunits      conda-forge/noarch::r-prettyunits-1.2.0-r42hc72bb7e_0
#   r-proc             conda-forge/osx-arm64::r-proc-1.18.0-r42h9a38a31_1
#   r-processx         conda-forge/osx-arm64::r-processx-3.8.4-r42hd2d937b_0
#   r-prodlim          conda-forge/osx-arm64::r-prodlim-2023.03.31-r42h9a38a31_0
#   r-progress         conda-forge/noarch::r-progress-1.2.3-r42hc72bb7e_0
#   r-progressr        conda-forge/noarch::r-progressr-0.14.0-r42hc72bb7e_0
#   r-promises         conda-forge/osx-arm64::r-promises-1.2.0.1-r42h9a38a31_1
#   r-proxy            conda-forge/osx-arm64::r-proxy-0.4_27-r42h21dc0da_2
#   r-pryr             conda-forge/osx-arm64::r-pryr-0.1.6-r42h9a38a31_0
#   r-ps               conda-forge/osx-arm64::r-ps-1.7.6-r42hd2d937b_0
#   r-purrr            conda-forge/osx-arm64::r-purrr-1.0.2-r42h21dc0da_0
#   r-quantmod         conda-forge/noarch::r-quantmod-0.4.26-r42hc72bb7e_0
#   r-r6               conda-forge/noarch::r-r6-2.5.1-r42hc72bb7e_2
#   r-randomforest     conda-forge/osx-arm64::r-randomforest-4.7_1.1-r42h505ec0b_1
#   r-rappdirs         conda-forge/osx-arm64::r-rappdirs-0.3.3-r42h21dc0da_2
#   r-rbokeh           conda-forge/noarch::r-rbokeh-0.5.2-r42hc72bb7e_3
#   r-rcolorbrewer     conda-forge/noarch::r-rcolorbrewer-1.1_3-r42h785f33e_2
#   r-rcpp             conda-forge/osx-arm64::r-rcpp-1.0.10-r42h9a38a31_0
#   r-readr            conda-forge/osx-arm64::r-readr-2.1.4-r42h9a38a31_0
#   r-readxl           conda-forge/osx-arm64::r-readxl-1.4.2-r42h815e8a2_0
#   r-recipes          conda-forge/noarch::r-recipes-1.0.10-r42hc72bb7e_0
#   r-recommended      conda-forge/noarch::r-recommended-4.2-r42hd8ed1ab_1006
#   r-rematch          conda-forge/noarch::r-rematch-2.0.0-r42hc72bb7e_0
#   r-rematch2         conda-forge/noarch::r-rematch2-2.1.2-r42hc72bb7e_3
#   r-repr             conda-forge/noarch::r-repr-1.1.7-r42h785f33e_0
#   r-reprex           conda-forge/noarch::r-reprex-2.1.0-r42hc72bb7e_0
#   r-reshape2         conda-forge/osx-arm64::r-reshape2-1.4.4-r42h9a38a31_2
#   r-rlang            conda-forge/osx-arm64::r-rlang-1.1.0-r42h9a38a31_0
#   r-rmarkdown        conda-forge/noarch::r-rmarkdown-2.27-r42hc72bb7e_0
#   r-rpart            conda-forge/osx-arm64::r-rpart-4.1.23-r42hd2d937b_0
#   r-rstudioapi       conda-forge/noarch::r-rstudioapi-0.16.0-r42hc72bb7e_0
#   r-rvest            conda-forge/noarch::r-rvest-1.0.4-r42hc72bb7e_0
#   r-sass             conda-forge/osx-arm64::r-sass-0.4.5-r42h9a38a31_0
#   r-scales           conda-forge/noarch::r-scales-1.3.0-r42hc72bb7e_0
#   r-selectr          conda-forge/noarch::r-selectr-0.4_2-r42hc72bb7e_3
#   r-shape            conda-forge/noarch::r-shape-1.4.6.1-r42ha770c72_0
#   r-shiny            conda-forge/noarch::r-shiny-1.8.1.1-r42h785f33e_0
#   r-sourcetools      conda-forge/osx-arm64::r-sourcetools-0.1.7_1-r42h9a38a31_0
#   r-spatial          conda-forge/osx-arm64::r-spatial-7.3_17-r42h21dc0da_0
#   r-squarem          conda-forge/noarch::r-squarem-2021.1-r42hc72bb7e_2
#   r-stringi          conda-forge/osx-arm64::r-stringi-1.7.12-r42ha4a7437_0
#   r-stringr          conda-forge/noarch::r-stringr-1.5.1-r42h785f33e_0
#   r-survival         conda-forge/osx-arm64::r-survival-3.7_0-r42h07cda29_0
#   r-sys              conda-forge/osx-arm64::r-sys-3.4.2-r42h21dc0da_1
#   r-tibble           conda-forge/osx-arm64::r-tibble-3.2.1-r42h21dc0da_2
#   r-tidyr            conda-forge/osx-arm64::r-tidyr-1.3.0-r42h9a38a31_0
#   r-tidyselect       conda-forge/noarch::r-tidyselect-1.2.1-r42hc72bb7e_0
#   r-tidyverse        conda-forge/noarch::r-tidyverse-1.3.2-r42hc72bb7e_1
#   r-timechange       conda-forge/osx-arm64::r-timechange-0.2.0-r42h9a38a31_0
#   r-timedate         conda-forge/noarch::r-timedate-4032.109-r42hc72bb7e_0
#   r-tinytex          conda-forge/noarch::r-tinytex-0.51-r42hc72bb7e_0
#   r-triebeard        conda-forge/osx-arm64::r-triebeard-0.4.1-r42h9a38a31_0
#   r-ttr              conda-forge/osx-arm64::r-ttr-0.24.4-r42hd2d937b_0
#   r-tzdb             conda-forge/osx-arm64::r-tzdb-0.3.0-r42h9a38a31_1
#   r-urltools         conda-forge/osx-arm64::r-urltools-1.7.3-r42h9a38a31_3
#   r-utf8             conda-forge/osx-arm64::r-utf8-1.2.4-r42hd2d937b_0
#   r-uuid             conda-forge/osx-arm64::r-uuid-1.2_0-r42hd2d937b_0
#   r-vctrs            conda-forge/osx-arm64::r-vctrs-0.6.1-r42h9a38a31_0
#   r-viridislite      conda-forge/noarch::r-viridislite-0.4.2-r42hc72bb7e_1
#   r-vroom            conda-forge/osx-arm64::r-vroom-1.6.1-r42h9a38a31_0
#   r-withr            conda-forge/noarch::r-withr-3.0.0-r42hc72bb7e_0
#   r-xfun             conda-forge/osx-arm64::r-xfun-0.38-r42h9a38a31_0
#   r-xml2             conda-forge/osx-arm64::r-xml2-1.3.3-r42haf93cbb_2
#   r-xtable           conda-forge/noarch::r-xtable-1.8_4-r42hc72bb7e_5
#   r-xts              conda-forge/osx-arm64::r-xts-0.14.0-r42h07cda29_0
#   r-yaml             conda-forge/osx-arm64::r-yaml-2.3.8-r42hd2d937b_0
#   r-zoo              conda-forge/osx-arm64::r-zoo-1.8_12-r42h21dc0da_1
#   rpy2               conda-forge/osx-arm64::rpy2-3.5.11-py311r42hb49d859_3
#   semver             conda-forge/noarch::semver-3.0.4-pyhcf101f3_1
#   simplegeneric      conda-forge/noarch::simplegeneric-0.8.1-pyhd8ed1ab_2
#   tktable            conda-forge/osx-arm64::tktable-2.10-hd996620_4
#   tzlocal            conda-forge/noarch::tzlocal-5.3.1-pyh8f84b5b_0
#
# The following packages will be REMOVED:
#
#   libboost-1.73.0-h49e8a49_12
#
# The following packages will be UPDATED:
#
#   anaconda-cloud-au~ pkgs/main/osx-arm64::anaconda-cloud-a~ --> conda-forge/noarch::anaconda-cloud-auth-0.5.0-pyhd8ed1ab_1
#   boost-cpp          pkgs/main::boost-cpp-1.73.0-h1a28f6b_~ --> conda-forge::boost-cpp-1.81.0-hf96b251_0
#   ca-certificates    conda-forge/osx-arm64::ca-certificate~ --> conda-forge/noarch::ca-certificates-2026.1.4-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2026.1.4-pyhd8ed1ab_0
#   gettext              pkgs/main::gettext-0.21.0-h13f89a0_1 --> conda-forge::gettext-0.21.1-h0186832_0
#   glib                    pkgs/main::glib-2.69.1-h514c7bf_2 --> conda-forge::glib-2.76.1-hb5ab8b9_0
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.1-h3~ --> conda-forge::gst-plugins-base-1.22.0-h8b7775e_2
#   gstreamer          pkgs/main::gstreamer-1.14.1-h80987f9_1 --> conda-forge::gstreamer-1.22.0-hcb7b3dd_2
#   icu                        pkgs/main::icu-68.1-hc377ac9_0 --> conda-forge::icu-70.1-h6b3803e_0
#   libiconv              pkgs/main::libiconv-1.16-h1a28f6b_2 --> conda-forge::libiconv-1.18-h23cfdf5_2
#   libpq                   pkgs/main::libpq-12.15-h02f6b3c_1 --> conda-forge::libpq-15.3-h7126958_1
#   qt-main              pkgs/main::qt-main-5.15.2-h9b4df51_9 --> conda-forge::qt-main-5.15.8-hfe8d25c_6
#   qtwebkit             pkgs/main::qtwebkit-5.212-h19f419d_5 --> conda-forge::qtwebkit-5.212-hbfb98c5_8
#   zlib                    pkgs/main::zlib-1.2.13-h5a0b063_0 --> conda-forge::zlib-1.2.13-hfb2fe0b_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-23.7.4-py311hca03da5~ --> conda-forge::conda-23.7.4-py311h267d04e_0
#   libsolv              pkgs/main::libsolv-0.7.24-h514c7bf_0 --> conda-forge::libsolv-0.7.24-hb5ab8b9_0
#   libxml2              pkgs/main::libxml2-2.10.4-h372ba2a_0 --> conda-forge::libxml2-2.10.3-h67585b2_4
#   libxslt              pkgs/main::libxslt-1.1.37-habca612_0 --> conda-forge::libxslt-1.1.37-h1bd8bc4_0
#   lxml                pkgs/main::lxml-4.9.3-py311h50ffb84_0 --> conda-forge::lxml-4.9.2-py311h246f609_0
#   pcre2                   pkgs/main::pcre2-10.42-hb066dcc_0 --> conda-forge::pcre2-10.40-hb34f9b4_0
#   python                pkgs/main::python-3.11.5-hb885b13_0 --> conda-forge::python-3.11.5-h47c9636_0_cpython
#
# The following packages will be DOWNGRADED:
#
#   openssl                                  3.4.0-h81ee809_1 --> 3.1.8-h81ee809_0
#
#
#
# Downloading and Extracting Packages
# r-backports-1.5.0    | 126 KB    |                                       |   0%
# libclang-cpp14-14.0. | 13.1 MB   |                                       |   0%
#
# r-rcpp-1.0.10        | 1.9 MB    |                                       |   0%
#
#
# tzlocal-5.3.1        | 23 KB     |                                       |   0%
#
#
#
# r-cachem-1.1.0       | 73 KB     |                                       |   0%
#
#
#
#
# r-rematch-2.0.0      | 24 KB     |                                       |   0%
#
#
#
#
#
# r-survival-3.7_0     | 6.0 MB    |                                       |   0%
#
#
#
#
#
#
# r-openssl-2.1.1      | 670 KB    |                                       |   0%
#
#
#
#
#
#
#
# r-clipr-0.8.0        | 67 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# r-numderiv-2016.8_1. | 125 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# r-broom-1.0.6        | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# r-bit64-4.0.5        | 470 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# r-readxl-1.4.2       | 708 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 400 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _r-mutex-1.0.1       | 3 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-gtable-0.3.5       | 217 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-proxy-0.4_27       | 179 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-cpp11-0.5.2        | 229 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-plyr-1.8.8         | 836 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-prodlim-2023.03.31 | 421 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.11      | 7 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-nlme-3.1_162       | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-sourcetools-0.1.7_ | 50 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# tzlocal-5.3.1        | 23 KB     | #########################3            |  69%
#
#
# r-backports-1.5.0    | 126 KB    | ####7                                 |  13%
#
#
#
#
# r-rematch-2.0.0      | 24 KB     | ########################3             |  66%
#
#
#
#
# r-rematch-2.0.0      | 24 KB     | ##################################### | 100%
# r-backports-1.5.0    | 126 KB    | ##################################### | 100%
#
#
#
#
#
# r-survival-3.7_0     | 6.0 MB    |                                       |   0%
#
#
#
# r-cachem-1.1.0       | 73 KB     | ########                              |  22%
# libclang-cpp14-14.0. | 13.1 MB   | #######5                              |  20%
#
#
#
# r-cachem-1.1.0       | 73 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# r-clipr-0.8.0        | 67 KB     | ########8                             |  24%
#
#
#
#
#
# r-survival-3.7_0     | 6.0 MB    | #####9                                |  16%
# libclang-cpp14-14.0. | 13.1 MB   | ####################3                 |  55%
#
# r-rcpp-1.0.10        | 1.9 MB    | 2                                     |   1%
#
#
#
#
#
#
#
# r-clipr-0.8.0        | 67 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# r-numderiv-2016.8_1. | 125 KB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
# r-numderiv-2016.8_1. | 125 KB    | ##################################### | 100%
# libclang-cpp14-14.0. | 13.1 MB   | ####################################  |  97%
#
# r-rcpp-1.0.10        | 1.9 MB    | #7                                    |   5%
#
#
#
#
#
# r-survival-3.7_0     | 6.0 MB    | ##################################### | 100%
#
#
#
#
#
# r-survival-3.7_0     | 6.0 MB    | ##################################### | 100%
#
#
#
#
#
#
# r-openssl-2.1.1      | 670 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
# r-broom-1.0.6        | 1.7 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
# r-bit64-4.0.5        | 470 KB    | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
# r-bit64-4.0.5        | 470 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 400 KB    | #4                                    |   4%
#
# r-rcpp-1.0.10        | 1.9 MB    | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _r-mutex-1.0.1       | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
# r-openssl-2.1.1      | 670 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# r-broom-1.0.6        | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# _r-mutex-1.0.1       | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-gtable-0.3.5       | 217 KB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 400 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-gtable-0.3.5       | 217 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-cpp11-0.5.2        | 229 KB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-cpp11-0.5.2        | 229 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-proxy-0.4_27       | 179 KB    | ###3                                  |   9%
#
# r-rcpp-1.0.10        | 1.9 MB    | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-proxy-0.4_27       | 179 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.11      | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.11      | 7 KB      | ##################################### | 100%
#
# r-rcpp-1.0.10        | 1.9 MB    | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
# r-readxl-1.4.2       | 708 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# r-readxl-1.4.2       | 708 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-plyr-1.8.8         | 836 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-plyr-1.8.8         | 836 KB    | ##################################### | 100%
# r-prodlim-2023.03.31 | 421 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-prodlim-2023.03.31 | 421 KB    | ##################################### | 100%
#
# r-rcpp-1.0.10        | 1.9 MB    | ##################################### | 100%
#
# r-rcpp-1.0.10        | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-nlme-3.1_162       | 2.2 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-sourcetools-0.1.7_ | 50 KB     | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-sourcetools-0.1.7_ | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-nlme-3.1_162       | 2.2 MB    | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# r-nlme-3.1_162       | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libclang-cpp14-14.0. | 13.1 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Enable R execution inside the notebook (rpy2)**

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# **Compute phylogenetic PCA**

# %%
# %%R -o pcs
# library(ape)
#
# tree <- read.tree("https://raw.githubusercontent.com/martinezrubio/ECOTREX/main/data/raw/ecotrex_tree.nwk")
# V <- vcv(tree)
# pca <- prcomp(V, scale.=TRUE)
#
# pcs <- as.data.frame(pca$x[, 1:12])
# colnames(pcs) <- paste0("PC", 1:12)
# pcs$species <- rownames(V)

# %%
pcs.head()
# Out:
#                                  PC1         PC2       PC3       PC4  \
# Megalapteryx_didinus     -206.274554 -108.923832 -1.743762 -0.317601
# Euryapteryx_curtus       -206.291422 -108.951216 -1.745061 -0.317972
# Emeus_crassus            -206.291422 -108.951216 -1.745061 -0.317972
# Anomalopteryx_didiformis -206.290785 -108.950181 -1.745012 -0.317958
# Pachyornis_geranoides    -206.289058 -108.947378 -1.744879 -0.317920
#
#                                PC5       PC6       PC7       PC8        PC9  \
# Megalapteryx_didinus      3.892841 -0.483482  0.660844 -3.653352  13.554580
# Euryapteryx_curtus        3.898758 -0.484266  0.662108 -3.662704  13.602923
# Emeus_crassus             3.898758 -0.484266  0.662108 -3.662704  13.602923
# Anomalopteryx_didiformis  3.898534 -0.484236  0.662060 -3.662350  13.601096
# Pachyornis_geranoides     3.897929 -0.484156  0.661931 -3.661393  13.596148
#
#                                PC10       PC11       PC12  \
# Megalapteryx_didinus     -76.396884  85.771716 -10.984549
# Euryapteryx_curtus       -76.694778  86.145266 -11.048494
# Emeus_crassus            -76.694778  86.145266 -11.048494
# Anomalopteryx_didiformis -76.683523  86.131152 -11.046078
# Pachyornis_geranoides    -76.653032  86.092918 -11.039533
#
#                                            species
# Megalapteryx_didinus          Megalapteryx_didinus
# Euryapteryx_curtus              Euryapteryx_curtus
# Emeus_crassus                        Emeus_crassus
# Anomalopteryx_didiformis  Anomalopteryx_didiformis
# Pachyornis_geranoides        Pachyornis_geranoides

# %% [markdown]
# **Merge phylogenetic PCs with the main dataset**

# %%
data = data.merge(pcs, left_on="Species", right_on="species", how="left").drop(columns=["species"])

# %%
data.columns
# Out:
# Index(['Species', 'Family', 'Order', 'log_Beak.Length_Culmen',
#        'log_Beak.Width', 'log_Beak.Depth', 'log_Tarsus.Length',
#        'log_Wing.Length', 'log_Kipps.Distance', 'log_Tail.Length', 'log_Mass',
#        'Island_Endemicity', 'Flight_Ability', 'fly', 'swim', 'walk', 'seabird',
#        'dn.cat', 'fd.cat', 'Pa', 'Pt', 'Ne', 'Se', 'Fr', 'In', 'Ap', 'Vt',
#        'PAG', 'PAS', 'PAD', 'PEL', 'PGR', 'NAE', 'NGL', 'SEL', 'SGR', 'FAE',
#        'FGL', 'FGR', 'IAE', 'ISA', 'ISS', 'ISG', 'IVS', 'IGE', 'IGG', 'APA',
#        'APL', 'APP', 'APG', 'APS', 'APD', 'VAE', 'VAS', 'VPE', 'VGE', 'VGG',
#        'CAQ', 'CGR', 'diet_simple', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6',
#        'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12'],
#       dtype='object')

# %% [markdown]
# ## 1.6 Final dataset assembly
#
# Relevant taxonomic, morphological, ecological, dietary, spatial, and phylogenetic variables were selected and explicitly ordered to define the final analysis-ready dataset used in downstream modelling.

# %%
final_columns = [
    "Species", "Family", "Order",
    "Island_Endemicity", "Flight_Ability",
    "log_Beak.Length_Culmen", "log_Beak.Width", "log_Beak.Depth",
    "log_Tarsus.Length", "log_Wing.Length", "log_Kipps.Distance", "log_Tail.Length", "log_Mass",

    "IAE", "ISA", "ISS", "ISG", "IVS", "IGE", "IGG",
    "APG", "APP", "APA", "APL", "APS", "APD",
    "FAE", "FGL", "FGR",
    "NAE", "NGL", "SEL", "SGR",
    "PEL", "PGR", "PAG", "PAS", "PAD",
    "VAE", "VAS", "VPE", "VGE", "VGG",
    "CAQ", "CGR",

    "In", "Ap", "Vt", "Ne", "Fr", "Se", "Pa", "Pt",

    "dn.cat", "fd.cat",
    "fly", "swim", "walk", "seabird",

    "PC1", "PC2", "PC3", "PC4", "PC5", "PC6",
    "PC7", "PC8", "PC9", "PC10", "PC11", "PC12"
]

# %%
data = data[final_columns]

# %%
data.columns.tolist()
# Out:
# ['Species',
#  'Family',
#  'Order',
#  'Island_Endemicity',
#  'Flight_Ability',
#  'log_Beak.Length_Culmen',
#  'log_Beak.Width',
#  'log_Beak.Depth',
#  'log_Tarsus.Length',
#  'log_Wing.Length',
#  'log_Kipps.Distance',
#  'log_Tail.Length',
#  'log_Mass',
#  'IAE',
#  'ISA',
#  'ISS',
#  'ISG',
#  'IVS',
#  'IGE',
#  'IGG',
#  'APG',
#  'APP',
#  'APA',
#  'APL',
#  'APS',
#  'APD',
#  'FAE',
#  'FGL',
#  'FGR',
#  'NAE',
#  'NGL',
#  'SEL',
#  'SGR',
#  'PEL',
#  'PGR',
#  'PAG',
#  'PAS',
#  'PAD',
#  'VAE',
#  'VAS',
#  'VPE',
#  'VGE',
#  'VGG',
#  'CAQ',
#  'CGR',
#  'In',
#  'Ap',
#  'Vt',
#  'Ne',
#  'Fr',
#  'Se',
#  'Pa',
#  'Pt',
#  'dn.cat',
#  'fd.cat',
#  'fly',
#  'swim',
#  'walk',
#  'seabird',
#  'PC1',
#  'PC2',
#  'PC3',
#  'PC4',
#  'PC5',
#  'PC6',
#  'PC7',
#  'PC8',
#  'PC9',
#  'PC10',
#  'PC11',
#  'PC12']

# %% [markdown]
# ## 1.7 Save AVONET pre-processed dataset

# %%
data.to_csv("/Users/nataliamartinezrubio/Library/CloudStorage/GoogleDrive-natalia.maru3101@gmail.com/Mi unidad/Work/CREAF/A_Extinctions/F_EcoTrEx/C_RandomForest/F_GitHub/avonet_processed.csv", index=False)
